# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv('/Users/morgan/Desktop/SEIS 763 ML/posting_32556_salary_info& company info.csv',header=0)

# %%
df.head()
# Out:
#       job_id              company_name  \
# 0     921716     Corcoran Sawyer Smith
# 1   10998357    The National Exemplar
# 2   23221523    Abrams Fensterman, LLP
# 3  103254301                Raw Cereal
# 4   95428182  CLEVELAND KIDS BOOK BANK
#
#                                                title  \
# 0                              Marketing Coordinator
# 1                        Assitant Restaurant Manager
# 2  Senior Elder Law / Trusts and Estates Associat...
# 3                                           Producer
# 4                         Administrative Coordinator
#
#                                          description  max_salary  \
# 0  Job descriptionA leading real estate firm in N...     41600.0
# 1  The National Exemplar is accepting application...     65000.0
# 2  Senior Associate Attorney - Elder Law / Trusts...    175000.0
# 3  Company DescriptionRaw Cereal is a creative de...    300000.0
# 4  Job Title: Administrative CoordinatorOrganizat...         NaN
#
#             location  company_id  views  min_salary formatted_work_type  ...  \
# 0      Princeton, NJ   2774458.0   20.0     35360.0           Full-time  ...
# 1     Cincinnati, OH  64896719.0    8.0     45000.0           Full-time  ...
# 2  New Hyde Park, NY    766262.0   16.0    140000.0           Full-time  ...
# 3      United States  81942316.0    7.0     60000.0            Contract  ...
# 4      Cleveland, OH  55624331.0    1.0         NaN           Full-time  ...
#
#   headquarter state country headquarter city headquarter zipcode  \
# 0                NJ      US      Jersey City               07302
# 1              Ohio      US        Mariemont               45227
# 2          New York      US     Lake Success               11042
# 3                CA      US     Los Angeles                90017
# 4              Ohio      US        Cleveland               44114
#
#     headquarter addr                  industry  \
# 0   242 Tenth Street               Real Estate
# 1  6880 Wooster Pike               Restaurants
# 2     3 Dakota Drive              Law Practice
# 3                  0           Design Services
# 4   3635 PERKINS AVE  Non-profit Organizations
#
#                                           speciality  employee_count  \
# 0                       real estate, new development             402
# 1                                                NaN              15
# 2  Civil Litigation, Corporate & Securities Law, ...             222
# 3                                                NaN              11
# 4                                                NaN               6
#
#   follower_count            time_recorded
# 0           2351  1970-01-20 19:56:49.275
# 1             40  1970-01-20 19:54:39.321
# 2           2427  1970-01-20 19:48:17.299
# 3            447  1970-01-20 19:47:41.202
# 4            289  1970-01-20 19:47:36.403
#
# [5 rows x 31 columns]

# %%
df.columns
# Out:
# Index(['job_id', 'company_name', 'title', 'description', 'max_salary',
#        'location', 'company_id', 'views', 'min_salary', 'formatted_work_type',
#        'original_listed_time', 'expiry', 'formatted_experience_level',
#        'listed_time', 'work_type', 'currency', 'normalized_salary', 'zip_code',
#        'name', 'company desc', 'company_size', 'headquarter state', 'country',
#        'headquarter city', 'headquarter zipcode', 'headquarter addr',
#        'industry', 'speciality', 'employee_count', 'follower_count',
#        'time_recorded'],
#       dtype='object')

# %%
import nltk

# %%
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
# Download NLTK data
#nltk.download('punkt')
#nltk.download('stopwords')

# %% [raw]
# '''# Define keyword lists
# # can be modified according to needs
# degree_keywords = ['bachelor', 'bs', 'ba', 'master', 'ms', 'phd', 'postgraduate','4-year']
# data_keywords = ['data analyst', 'data scientist', 'machine learning', 'big data', 'data engineer','intelligence','market research','data',
#                  'business analyst','insight','stitistical','statistics']
# hard_skills = ['python', 'r', 'sql', 'java', 'tableau', 'power bi', 'matlab', 'sas', 'pmp',
#                'aws certified','snowflake','crm','oracle','spss','cognos']'''

# %% [raw]
# '''# Function to preprocess and tokenize text
# def preprocess_text(text):
#     if pd.isnull(text):
#         return []
#     # Tokenize and remove stopwords
#     tokens = word_tokenize(text.lower())
#     stop_words = set(stopwords.words('english'))
#     filtered_tokens = [word for word in tokens if word not in stop_words and word.isalnum()]
#     return filtered_tokens
#
# # Function to search for keywords in tokenized text
# def keyword_search_nltk(tokens, keywords):
#     return [kw for kw in keywords if kw in tokens]'''

# %% [raw]
# ''' Preprocess job descriptions
# df['tokenized_description'] = df['description'].apply(preprocess_text)
#
# # Extract degree requirements
# df['degree_required'] = df['tokenized_description'].apply(lambda x: int(any(keyword_search_nltk(x, degree_keywords))))
#
# # Extract hard skills
# df['hard_skills'] = df['tokenized_description'].apply(lambda x: keyword_search_nltk(x, hard_skills))
#
# # Identify data-related jobs
# df['is_data_related'] = df['tokenized_description'].apply(lambda x: int(any(keyword_search_nltk(x, data_keywords))))'''

# %% [raw]
# '''# Extract years of experience using regex
# def extract_years_experience_nltk(text):
#     if pd.isnull(text):
#         return None
#     match = re.search(r'(\d+)\s+years? of experience', text.lower())
#     return int(match.group(1)) if match else None
#
# df['years_experience'] = df['description'].apply(extract_years_experience_nltk)'''

# %% [raw]
# """# Add new columns for the extracted features
# df['degree_required'] = 0
# df['degree_level'] = 'None'
# df['required_major'] = 'None'
# df['is_data_related'] = 0
# df['domains_technologies'] = ''
# df['hard_skills_programming'] = ''
# df['hard_skills_analysis'] = ''
# df['hard_skills_ml_ai'] = ''
# df['hard_skills_viz'] = ''
# df['hard_skills_cloud'] = ''
# df['hard_skills_database'] = ''
# df['hard_skills_big_data'] = ''
# df['soft_skills_mentioned'] = 0"""

# %%
# Define keyword lists for extraction and classification
degree_keywords =  {
    "bachelor": ["bachelor", "undergraduate","4 year"],
    "postgraduate": ["master", "postgraduate", "phd", "doctorate","mba"],
}

major_keywords = ["data science", "artificial intelligence", "MIS", "analytics", "business analysis","information system"]

data_keywords = ["data"]

hard_skills = {
    "programming_languages": ["python", "java", "c++", "r", "sql", "javascript","matlab"],
    "analysis_statistics": ["excel", "tableau", "statistics", "sas", "spss","regression","decision tree","predictive analysis",
                            "statistics","statistical",'models'],
    "machine_learning": ["tensorflow", "keras", "scikit-learn", "pytorch", "deep learning","nlp","svm",
                         "clustering","natural language","machine learning", "deeep learning","ai"],
    "data_visualization": ["power bi", "matplotlib", "seaborn", "dash","tableau","cognos",'bi'],
    "cloud_platform": ["aws", "azure", "google cloud","crm","cloud computing"],
    "database": ["dataset","mysql", "postgresql", "mongodb", "oracle","sql","database","query"],
    "big_data": ["hadoop", "spark", "big data", "kafka","bigquery"]
}

soft_skills = ["communication", "teamwork", "problem-solving", "adaptability", "leadership", "creativity","detail","deadline","collaboration"]

"""business_keywords = [
    "business analysis", "market", "strategy", "management", "finance",
    "operation", "sales", "marketing", "client", "consulting", "stakeholder",
    "crm", "leadership", "planning", "kpi","agile","project management","market research",
    "interlligence","business analysis", "mba", "market", "excel","dax","jira","erp","customer", "google analysis","visio",
    "azure"
]

engineering_keywords = [
    "developer", "engineer", "scientist","software", "programming", "ai", "ml", "database",
    "backend", "frontend", "data structures", "cloud", "API", "integration",
    "ETL", "devops", "algorithm", "distributed systems", "coding", "developer"
]"""
# Out:
# 'business_keywords = [\n    "business analysis", "market", "strategy", "management", "finance",\n    "operation", "sales", "marketing", "client", "consulting", "stakeholder",\n    "crm", "leadership", "planning", "kpi","agile","project management","market research",\n    "interlligence","business analysis", "mba", "market", "excel","dax","jira","erp","customer", "google analysis","visio",\n    "azure"\n]\n\nengineering_keywords = [\n    "developer", "engineer", "scientist","software", "programming", "ai", "ml", "database",\n    "backend", "frontend", "data structures", "cloud", "API", "integration",\n    "ETL", "devops", "algorithm", "distributed systems", "coding", "developer"\n]'

# %%
# Add scoring columns
def initialize_columns(df):
    # Ensure all extracted feature columns are initialized with appropriate data types
    df['degree_level'] = ""  # Default is an empty string for degree levels
    df['is_data_related'] = False  # Initialize as boolean
    df['job_classification'] = ""  # Default is an empty string
    df['soft_skills'] = ""  # Default is an empty string

    # Initialize score columns with integers (default 0)
    df['programming_languages_score'] = 0
    df['analysis_statistics_score'] = 0
    df['machine_learning_score'] = 0
    df['data_visualization_score'] = 0
    df['cloud_platform_score'] = 0
    df['database_score'] = 0
    df['big_data_tools_score'] = 0
    
    hard_skills_categories = list(hard_skills.keys())
    for category in hard_skills_categories:
        df[f"{category}_score"] = 0
    df['business_engineering_score'] = 0
    return df

# %% [raw]
# def classify_job(description):
#     """
#     Classifies a job as 'Business' or 'Engineering/Software' based on the description.
#     """
#     if pd.isna(description):  # Check if the description is NaN
#         return "Unknown"
#
#     # Ensure the description is a string before processing
#     description = str(description).lower()
#
#     # Keywords for classification
#     business_keywords = ["business analysis", "market", "strategy", "management", "finance",
#                          "operation", "sales", "marketing", "client", "consulting", "stakeholder",
#                          "crm", "leadership", "planning", "kpi","agile","project management","market research",
#                          "interlligence","business analysis", "mba", "market", "excel","dax","jira","erp","customer",
#                          "google analysis","visio","azure","specialist","consultant","financial","business"
#                         ]
#     engineering_keywords = ["developer", "engineer", "scientist","software", "programming", "ai", "ml", "database",
#                             "backend", "frontend", "data structures", "cloud", "api", "integration",
#                             "etl", "devops", "algorithm", "distributed systems", "coding", "developer"
#                            ]
#     # Check for keywords
#     if any(keyword in description for keyword in engineering_keywords):
#         return "Engineering"
#     elif any(keyword in description for keyword in business_keywords):
#         return "Business"
#     else:
#         return "Unknown"

# %%
def classify_job(title, description):
    """
    Classifies a job into 'Business' or 'Engineering' based on keywords.

    Args:
        title: The job title.
        description: The job description.

    Returns:
        'Business' or 'Engineering'
    """

    description = str(description).lower()
    title = str(title).lower()
    
    engineering_keywords = [
        "developer", "engineer", "software", "programming", "ai", "ml", "database",
        "backend", "frontend", "cloud", "api", "integration", "etl", "devops", "algorithm",
        "distributed systems", "coding", "data mining", "data structures"
    ]
    
    business_keywords = [
        "business strategy", "market research", "kpi", "stakeholder management", 
        "client engagement", "financial modeling", "sales pipeline", 
        "consulting", "mba", "leadership", "planning", "marketing campaign","business analysis",
        "business interlligence"
    ]

    
    # Combine keywords and job title for comprehensive analysis
    text = f"{str(title).lower()} {str(description).lower()}"
    
    engineering_score = sum(keyword in text for keyword in engineering_keywords)
    business_score = sum(keyword in text for keyword in business_keywords)
    
    if engineering_score > business_score:
        return "Engineering"
    elif business_score > engineering_score:
        return "Business"
    else:
        return "Other"

# %%
#df['Job Category'] = df.apply(lambda x: classify_job(x['title'], x['description']), axis=1)

# %%
#df[df['Job Category']=="Engineering"]

# %%
# Function to extract and score information
def extract_info_with_scores(description):
    degree = []
    data_related = False
    category_scores = {category: 0 for category in hard_skills.keys()}
    extracted_soft_skills = []
    
    if isinstance(description, str):
        description_lower = description.lower()
        
        # Degree keywords
        for word in degree_keywords:
            if word in description_lower:
                degree.append(word)
        
        # Data-related keywords
        for word in data_keywords:
            if word in description_lower:
                data_related = True

        # Hard skills scoring
        for category, keywords in hard_skills.items():
            for keyword in keywords:
                if keyword in description_lower:
                    category_scores[category] += 1
        
        # Soft skills extraction
        for skill in soft_skills:
            if skill in description_lower:
                extracted_soft_skills.append(skill)
    
    return degree, data_related, category_scores, extracted_soft_skills

# %%
# Apply processing
def process_job_postings(df):
    # Initialize columns
    df = initialize_columns(df)
    
    # Loop through rows
    for idx, row in df.iterrows():
        description = row['description']
        
        # Extract information and scores
        degree, data_related, category_scores, soft_skills_extracted = extract_info_with_scores(description)
        job_classification = classify_job(row['title'], row['description'])
        
        # Update columns
        df.at[idx, 'degree_level'] = ', '.join(degree)
        df.at[idx, 'is_data_related'] = data_related
        df.at[idx, 'soft_skills'] = ', '.join(soft_skills_extracted)
        df.at[idx, 'job_classification'] = job_classification
        
        # Update hard skill scores
        for category, score in category_scores.items():
            df.at[idx, f"{category}_score"] = score
    
    return df

# %%
df = process_job_postings(df)

# %%
df.shape
# Out:
# (32555, 44)

# %%
business_jobs=df[(df['job_classification']== "Business")&(df['is_data_related']==True)]
business_jobs
# Out:
#            job_id                              company_name  \
# 44     3514683108                                     AVAVA
# 195    3862107843                                Swipeclock
# 215    3870701883  EmazingGroup - INTO THE AM & iHeartRaves
# 217    3871144579                             World of Reza
# 333    3884432698                           Dahl Consulting
# ...           ...                                       ...
# 32393  3906257446                                   KeyBank
# 32400  3906257580                       Advantage Solutions
# 32411  3906258100                                        TD
# 32438  3906258582                      Veolia North America
# 32527  3906261092                       Advantage Solutions
#
#                                         title  \
# 44                    Associate Brand Manager
# 195                           Product Manager
# 215                       Merchandise Planner
# 217                  Head of Client Relations
# 333           Full Manager Bookkeeper (26394)
# ...                                       ...
# 32393            Financial Wellness Associate
# 32400               Director, Client Services
# 32411             Senior Finance Analyst (US)
# 32438              Administrative Coordinator
# 32527  Manager Space and Assortment Analytics
#
#                                              description  max_salary  \
# 44     Job Title: Associate Brand Manager / Brand Man...     90000.0
# 195    Swipeclock is on a mission to make working lif...    120000.0
# 215    Top Reasons to Work with Us:\nSince 2010, the ...     75000.0
# 217    \nDo you have a passion for beautiful, timeles...    110000.0
# 333    Seeking a remote job opportunity? Check out th...     75000.0
# ...                                                  ...         ...
# 32393  Location:\n\n405 NW Gilman Boulevard - Issaqua...     45760.0
# 32400  Director Client Services \n\nAt our Company, w...    105000.0
# 32411  Work Location:\n\n1006 Astoria Boulevard\n\nHo...    112320.0
# 32438  Company Description\n\nAbout Veolia North Amer...     70000.0
# 32527  Manager, Space & Assortment Analytics \n\nAt o...     54000.0
#
#                               location  company_id  views  min_salary  \
# 44                         Waltham, MA  40692980.0    1.0     75000.0
# 195                   South Jordan, UT    940888.0    3.0    100000.0
# 215                        Anaheim, CA   3696072.0    7.0     65000.0
# 217    New York City Metropolitan Area  78331809.0    6.0     85000.0
# 333                      United States     29686.0   26.0     65000.0
# ...                                ...         ...    ...         ...
# 32393                     Issaquah, WA      3252.0    3.0     39520.0
# 32400                  Bentonville, AR      9123.0    4.0     75000.0
# 32411                      Astoria, OR      2775.0    5.0     68640.0
# 32438                   West Nyack, NY    508963.0    2.0     60000.0
# 32527                     St Louis, MO      9123.0    2.0     46000.0
#
#       formatted_work_type  ...  \
# 44              Full-time  ...
# 195             Full-time  ...
# 215             Full-time  ...
# 217             Full-time  ...
# 333             Full-time  ...
# ...                   ...  ...
# 32393           Full-time  ...
# 32400           Full-time  ...
# 32411           Full-time  ...
# 32438           Full-time  ...
# 32527           Full-time  ...
#
#                                              soft_skills  \
# 44            communication, problem-solving, leadership
# 195               communication, problem-solving, detail
# 215                       adaptability, detail, deadline
# 217                    communication, leadership, detail
# 333                              problem-solving, detail
# ...                                                  ...
# 32393  communication, teamwork, adaptability, leaders...
# 32400        communication, leadership, detail, deadline
# 32411  communication, teamwork, leadership, creativit...
# 32438                            communication, deadline
# 32527  communication, problem-solving, leadership, de...
#
#       programming_languages_score analysis_statistics_score  \
# 44                              1                         1
# 195                             1                         1
# 215                             1                         2
# 217                             1                         1
# 333                             1                         0
# ...                           ...                       ...
# 32393                           1                         1
# 32400                           1                         1
# 32411                           1                         0
# 32438                           1                         1
# 32527                           1                         2
#
#       machine_learning_score data_visualization_score cloud_platform_score  \
# 44                         1                        1                    1
# 195                        1                        1                    0
# 215                        1                        1                    1
# 217                        1                        1                    1
# 333                        1                        1                    1
# ...                      ...                      ...                  ...
# 32393                      1                        1                    0
# 32400                      1                        1                    0
# 32411                      1                        2                    0
# 32438                      1                        1                    0
# 32527                      1                        1                    0
#
#        database_score  big_data_tools_score big_data_score  \
# 44                  0                     0              0
# 195                 0                     0              0
# 215                 0                     0              0
# 217                 0                     0              0
# 333                 0                     0              0
# ...               ...                   ...            ...
# 32393               0                     0              0
# 32400               0                     0              0
# 32411               0                     0              0
# 32438               0                     0              0
# 32527               0                     0              0
#
#       business_engineering_score
# 44                             0
# 195                            0
# 215                            0
# 217                            0
# 333                            0
# ...                          ...
# 32393                          0
# 32400                          0
# 32411                          0
# 32438                          0
# 32527                          0
#
# [980 rows x 44 columns]

# %%
business_jobs.describe()
# Out:
#              job_id     max_salary    company_id        views     min_salary  \
# count  9.800000e+02     905.000000  9.800000e+02   974.000000     905.000000
# mean   3.899246e+09  146087.050751  1.012180e+07    47.102669  105470.384232
# std    1.406554e+07   72586.378800  2.351304e+07   392.957084   52175.203725
# min    3.514683e+09      35.000000  1.016000e+03     1.000000      30.000000
# 25%    3.895461e+09   95000.000000  5.304750e+03     4.000000   71289.000000
# 50%    3.902339e+09  135000.000000  1.641060e+05     5.000000   94900.000000
# 75%    3.904943e+09  184000.000000  3.706728e+06    15.000000  132300.000000
# max    3.906261e+09  520000.000000  1.026498e+08  9975.000000  416000.000000
#
#        normalized_salary      zip_code  company_size  employee_count  \
# count         980.000000    761.000000    944.000000      980.000000
# mean       123119.779122  52968.714849      5.010593    26781.190816
# std         61995.642655  33349.200463      2.084100    75891.326422
# min            32.500000   1201.000000      1.000000        1.000000
# 25%         80000.000000  20190.000000      3.000000      277.750000
# 50%        111300.000000  57201.000000      5.000000     2201.000000
# 75%        155000.000000  90001.000000      7.000000    22839.250000
# max        500000.000000  99501.000000      7.000000   748312.000000
#
#        follower_count  programming_languages_score  analysis_statistics_score  \
# count    9.800000e+02                   980.000000                 980.000000
# mean     9.789816e+05                     1.059184                   1.088776
# std      3.267192e+06                     0.297362                   0.842728
# min      1.400000e+01                     1.000000                   0.000000
# 25%      1.854000e+04                     1.000000                   1.000000
# 50%      1.100875e+05                     1.000000                   1.000000
# 75%      4.931160e+05                     1.000000                   1.000000
# max      3.270284e+07                     4.000000                   6.000000
#
#        machine_learning_score  data_visualization_score  cloud_platform_score  \
# count              980.000000                980.000000            980.000000
# mean                 0.969388                  1.148980              0.282653
# std                  0.249784                  0.484962              0.470482
# min                  0.000000                  0.000000              0.000000
# 25%                  1.000000                  1.000000              0.000000
# 50%                  1.000000                  1.000000              0.000000
# 75%                  1.000000                  1.000000              1.000000
# max                  3.000000                  4.000000              3.000000
#
#        database_score  big_data_tools_score  big_data_score  \
# count      980.000000                 980.0      980.000000
# mean         0.111224                   0.0        0.009184
# std          0.359997                   0.0        0.095439
# min          0.000000                   0.0        0.000000
# 25%          0.000000                   0.0        0.000000
# 50%          0.000000                   0.0        0.000000
# 75%          0.000000                   0.0        0.000000
# max          4.000000                   0.0        1.000000
#
#        business_engineering_score
# count                       980.0
# mean                          0.0
# std                           0.0
# min                           0.0
# 25%                           0.0
# 50%                           0.0
# 75%                           0.0
# max                           0.0

# %%
engineering_jobs=df[(df['job_classification']== "Engineering")&(df['is_data_related']==True)]
engineering_jobs
# Out:
#            job_id                                 company_name  \
# 4        95428182                     CLEVELAND KIDS BOOK BANK
# 11     1014822088                                      Tracker
# 13     1448163866                                 Genlabs Corp
# 18     2558399667                         I.T. Solutions, Inc.
# 22     2920450495  Grunwald Mechanical Contractors & Engineers
# ...           ...                                          ...
# 32537  3906262655                                  Vertisystem
# 32539  3906262691             TalentBurst, an Inc 5000 company
# 32540  3906263026                                   Applicantz
# 32546  3906265006                                   Applicantz
# 32547  3906265144                                   Applicantz
#
#                                     title  \
# 4              Administrative Coordinator
# 11                   Marketing Specialist
# 13                         Office Manager
# 18      Validation Engineer, Labware LIMS
# 22                    Service Coordinator
# ...                                   ...
# 32537         Human Resources Coordinator
# 32539          Senior Validation Engineer
# 32540               Desktop Test Engineer
# 32546      SAP FICO Functional Consultant
# 32547  Junior Employee Support Specialist
#
#                                              description  max_salary  \
# 4      Job Title: Administrative CoordinatorOrganizat...         NaN
# 11     About TrackerTracker is a leading global cloud...     80000.0
# 13     Responsibilities: • Oversees and manages all a...     70000.0
# 18     Validation Engineer, Labware LIMSFoster City, ...    145600.0
# 22     QualificationsExperience:Data Entry, 4 years (...     75000.0
# ...                                                  ...         ...
# 32537  JOB DESCRIPTION:Job Title:HR Recruiter - Profe...     72800.0
# 32539  Title: Validation Engineer III, Req#: ROCGJP00...    156000.0
# 32540  VISA SPONSORSHIP NOT AVAILABLE. Work to be don...     71718.4
# 32546  VISA SPONSORSHIP IS NOT AVAILABLE. Remote role...    186492.8
# 32547  Remote job. Candidate locations preferred are ...     46425.6
#
#               location  company_id  views  min_salary formatted_work_type  \
# 4        Cleveland, OH  55624331.0    1.0         NaN           Full-time
# 11       United States    255252.0    7.0     70000.0           Full-time
# 13           Chino, CA   4273342.0    3.0     65000.0           Full-time
# 18     Foster City, CA   2610793.0    NaN    124800.0            Contract
# 22           Omaha, NE  80316732.0    4.0     55000.0           Full-time
# ...                ...         ...    ...         ...                 ...
# 32537        Greer, SC   3009879.0    2.0     62400.0            Contract
# 32539    Oceanside, CA    122451.0    1.0    104000.0            Contract
# 32540    United States     24629.0    3.0     71718.4            Contract
# 32546    United States     24629.0    3.0    186492.8            Contract
# 32547    United States     24629.0    3.0     46425.6            Contract
#
#        ...                                       soft_skills  \
# 4      ...  communication, creativity, detail, collaboration
# 11     ...                                  detail, deadline
# 13     ...                             communication, detail
# 18     ...                                     communication
# 22     ...            communication, problem-solving, detail
# ...    ...                                               ...
# 32537  ...                                     communication
# 32539  ...  communication, teamwork, problem-solving, detail
# 32540  ...       communication, creativity, detail, deadline
# 32546  ...                                creativity, detail
# 32547  ...                 communication, creativity, detail
#
#       programming_languages_score analysis_statistics_score  \
# 4                               1                         1
# 11                              1                         0
# 13                              1                         1
# 18                              1                         0
# 22                              1                         1
# ...                           ...                       ...
# 32537                           1                         0
# 32539                           1                         2
# 32540                           1                         2
# 32546                           1                         1
# 32547                           1                         1
#
#       machine_learning_score data_visualization_score cloud_platform_score  \
# 4                          1                        1                    2
# 11                         1                        1                    1
# 13                         1                        1                    0
# 18                         0                        1                    0
# 22                         1                        1                    0
# ...                      ...                      ...                  ...
# 32537                      1                        1                    1
# 32539                      1                        1                    0
# 32540                      1                        1                    0
# 32546                      1                        1                    0
# 32547                      1                        1                    0
#
#        database_score  big_data_tools_score big_data_score  \
# 4                   1                     0              0
# 11                  0                     0              0
# 13                  0                     0              0
# 18                  1                     0              0
# 22                  0                     0              0
# ...               ...                   ...            ...
# 32537               0                     0              0
# 32539               0                     0              0
# 32540               0                     0              0
# 32546               0                     0              0
# 32547               0                     0              0
#
#       business_engineering_score
# 4                              0
# 11                             0
# 13                             0
# 18                             0
# 22                             0
# ...                          ...
# 32537                          0
# 32539                          0
# 32540                          0
# 32546                          0
# 32547                          0
#
# [9858 rows x 44 columns]

# %%
data_job=df[(df['is_data_related']==True) & (df['degree_level']!='')& (df['job_classification']!= "Unknown")]

# %%
data_job2=df[(df['is_data_related']==True) & (df['job_classification']!= "Unknown")]

# %%
data_job2.shape
# Out:
# (12684, 44)

# %%
data_job2[(data_job2['job_classification']== "Business")]
# Out:
#            job_id                              company_name  \
# 44     3514683108                                     AVAVA
# 195    3862107843                                Swipeclock
# 215    3870701883  EmazingGroup - INTO THE AM & iHeartRaves
# 217    3871144579                             World of Reza
# 333    3884432698                           Dahl Consulting
# ...           ...                                       ...
# 32393  3906257446                                   KeyBank
# 32400  3906257580                       Advantage Solutions
# 32411  3906258100                                        TD
# 32438  3906258582                      Veolia North America
# 32527  3906261092                       Advantage Solutions
#
#                                         title  \
# 44                    Associate Brand Manager
# 195                           Product Manager
# 215                       Merchandise Planner
# 217                  Head of Client Relations
# 333           Full Manager Bookkeeper (26394)
# ...                                       ...
# 32393            Financial Wellness Associate
# 32400               Director, Client Services
# 32411             Senior Finance Analyst (US)
# 32438              Administrative Coordinator
# 32527  Manager Space and Assortment Analytics
#
#                                              description  max_salary  \
# 44     Job Title: Associate Brand Manager / Brand Man...     90000.0
# 195    Swipeclock is on a mission to make working lif...    120000.0
# 215    Top Reasons to Work with Us:\nSince 2010, the ...     75000.0
# 217    \nDo you have a passion for beautiful, timeles...    110000.0
# 333    Seeking a remote job opportunity? Check out th...     75000.0
# ...                                                  ...         ...
# 32393  Location:\n\n405 NW Gilman Boulevard - Issaqua...     45760.0
# 32400  Director Client Services \n\nAt our Company, w...    105000.0
# 32411  Work Location:\n\n1006 Astoria Boulevard\n\nHo...    112320.0
# 32438  Company Description\n\nAbout Veolia North Amer...     70000.0
# 32527  Manager, Space & Assortment Analytics \n\nAt o...     54000.0
#
#                               location  company_id  views  min_salary  \
# 44                         Waltham, MA  40692980.0    1.0     75000.0
# 195                   South Jordan, UT    940888.0    3.0    100000.0
# 215                        Anaheim, CA   3696072.0    7.0     65000.0
# 217    New York City Metropolitan Area  78331809.0    6.0     85000.0
# 333                      United States     29686.0   26.0     65000.0
# ...                                ...         ...    ...         ...
# 32393                     Issaquah, WA      3252.0    3.0     39520.0
# 32400                  Bentonville, AR      9123.0    4.0     75000.0
# 32411                      Astoria, OR      2775.0    5.0     68640.0
# 32438                   West Nyack, NY    508963.0    2.0     60000.0
# 32527                     St Louis, MO      9123.0    2.0     46000.0
#
#       formatted_work_type  ...  \
# 44              Full-time  ...
# 195             Full-time  ...
# 215             Full-time  ...
# 217             Full-time  ...
# 333             Full-time  ...
# ...                   ...  ...
# 32393           Full-time  ...
# 32400           Full-time  ...
# 32411           Full-time  ...
# 32438           Full-time  ...
# 32527           Full-time  ...
#
#                                              soft_skills  \
# 44            communication, problem-solving, leadership
# 195               communication, problem-solving, detail
# 215                       adaptability, detail, deadline
# 217                    communication, leadership, detail
# 333                              problem-solving, detail
# ...                                                  ...
# 32393  communication, teamwork, adaptability, leaders...
# 32400        communication, leadership, detail, deadline
# 32411  communication, teamwork, leadership, creativit...
# 32438                            communication, deadline
# 32527  communication, problem-solving, leadership, de...
#
#       programming_languages_score analysis_statistics_score  \
# 44                              1                         1
# 195                             1                         1
# 215                             1                         2
# 217                             1                         1
# 333                             1                         0
# ...                           ...                       ...
# 32393                           1                         1
# 32400                           1                         1
# 32411                           1                         0
# 32438                           1                         1
# 32527                           1                         2
#
#       machine_learning_score data_visualization_score cloud_platform_score  \
# 44                         1                        1                    1
# 195                        1                        1                    0
# 215                        1                        1                    1
# 217                        1                        1                    1
# 333                        1                        1                    1
# ...                      ...                      ...                  ...
# 32393                      1                        1                    0
# 32400                      1                        1                    0
# 32411                      1                        2                    0
# 32438                      1                        1                    0
# 32527                      1                        1                    0
#
#        database_score  big_data_tools_score big_data_score  \
# 44                  0                     0              0
# 195                 0                     0              0
# 215                 0                     0              0
# 217                 0                     0              0
# 333                 0                     0              0
# ...               ...                   ...            ...
# 32393               0                     0              0
# 32400               0                     0              0
# 32411               0                     0              0
# 32438               0                     0              0
# 32527               0                     0              0
#
#       business_engineering_score
# 44                             0
# 195                            0
# 215                            0
# 217                            0
# 333                            0
# ...                          ...
# 32393                          0
# 32400                          0
# 32411                          0
# 32438                          0
# 32527                          0
#
# [980 rows x 44 columns]

# %%
data_job2[(data_job2['job_classification']== "Engineering")]
# Out:
#            job_id                                 company_name  \
# 4        95428182                     CLEVELAND KIDS BOOK BANK
# 11     1014822088                                      Tracker
# 13     1448163866                                 Genlabs Corp
# 18     2558399667                         I.T. Solutions, Inc.
# 22     2920450495  Grunwald Mechanical Contractors & Engineers
# ...           ...                                          ...
# 32537  3906262655                                  Vertisystem
# 32539  3906262691             TalentBurst, an Inc 5000 company
# 32540  3906263026                                   Applicantz
# 32546  3906265006                                   Applicantz
# 32547  3906265144                                   Applicantz
#
#                                     title  \
# 4              Administrative Coordinator
# 11                   Marketing Specialist
# 13                         Office Manager
# 18      Validation Engineer, Labware LIMS
# 22                    Service Coordinator
# ...                                   ...
# 32537         Human Resources Coordinator
# 32539          Senior Validation Engineer
# 32540               Desktop Test Engineer
# 32546      SAP FICO Functional Consultant
# 32547  Junior Employee Support Specialist
#
#                                              description  max_salary  \
# 4      Job Title: Administrative CoordinatorOrganizat...         NaN
# 11     About TrackerTracker is a leading global cloud...     80000.0
# 13     Responsibilities: • Oversees and manages all a...     70000.0
# 18     Validation Engineer, Labware LIMSFoster City, ...    145600.0
# 22     QualificationsExperience:Data Entry, 4 years (...     75000.0
# ...                                                  ...         ...
# 32537  JOB DESCRIPTION:Job Title:HR Recruiter - Profe...     72800.0
# 32539  Title: Validation Engineer III, Req#: ROCGJP00...    156000.0
# 32540  VISA SPONSORSHIP NOT AVAILABLE. Work to be don...     71718.4
# 32546  VISA SPONSORSHIP IS NOT AVAILABLE. Remote role...    186492.8
# 32547  Remote job. Candidate locations preferred are ...     46425.6
#
#               location  company_id  views  min_salary formatted_work_type  \
# 4        Cleveland, OH  55624331.0    1.0         NaN           Full-time
# 11       United States    255252.0    7.0     70000.0           Full-time
# 13           Chino, CA   4273342.0    3.0     65000.0           Full-time
# 18     Foster City, CA   2610793.0    NaN    124800.0            Contract
# 22           Omaha, NE  80316732.0    4.0     55000.0           Full-time
# ...                ...         ...    ...         ...                 ...
# 32537        Greer, SC   3009879.0    2.0     62400.0            Contract
# 32539    Oceanside, CA    122451.0    1.0    104000.0            Contract
# 32540    United States     24629.0    3.0     71718.4            Contract
# 32546    United States     24629.0    3.0    186492.8            Contract
# 32547    United States     24629.0    3.0     46425.6            Contract
#
#        ...                                       soft_skills  \
# 4      ...  communication, creativity, detail, collaboration
# 11     ...                                  detail, deadline
# 13     ...                             communication, detail
# 18     ...                                     communication
# 22     ...            communication, problem-solving, detail
# ...    ...                                               ...
# 32537  ...                                     communication
# 32539  ...  communication, teamwork, problem-solving, detail
# 32540  ...       communication, creativity, detail, deadline
# 32546  ...                                creativity, detail
# 32547  ...                 communication, creativity, detail
#
#       programming_languages_score analysis_statistics_score  \
# 4                               1                         1
# 11                              1                         0
# 13                              1                         1
# 18                              1                         0
# 22                              1                         1
# ...                           ...                       ...
# 32537                           1                         0
# 32539                           1                         2
# 32540                           1                         2
# 32546                           1                         1
# 32547                           1                         1
#
#       machine_learning_score data_visualization_score cloud_platform_score  \
# 4                          1                        1                    2
# 11                         1                        1                    1
# 13                         1                        1                    0
# 18                         0                        1                    0
# 22                         1                        1                    0
# ...                      ...                      ...                  ...
# 32537                      1                        1                    1
# 32539                      1                        1                    0
# 32540                      1                        1                    0
# 32546                      1                        1                    0
# 32547                      1                        1                    0
#
#        database_score  big_data_tools_score big_data_score  \
# 4                   1                     0              0
# 11                  0                     0              0
# 13                  0                     0              0
# 18                  1                     0              0
# 22                  0                     0              0
# ...               ...                   ...            ...
# 32537               0                     0              0
# 32539               0                     0              0
# 32540               0                     0              0
# 32546               0                     0              0
# 32547               0                     0              0
#
#       business_engineering_score
# 4                              0
# 11                             0
# 13                             0
# 18                             0
# 22                             0
# ...                          ...
# 32537                          0
# 32539                          0
# 32540                          0
# 32546                          0
# 32547                          0
#
# [9858 rows x 44 columns]

# %%
data_job[(data_job['job_classification']== "Business")]
# Out:
#            job_id         company_name  \
# 44     3514683108                AVAVA
# 195    3862107843           Swipeclock
# 441    3884435818                  MiQ
# 550    3884438827       Exact Sciences
# 551    3884438893        Planet Pharma
# ...           ...                  ...
# 32143  3906252922       Wolters Kluwer
# 32157  3906253168                 Visa
# 32159  3906253175                 Visa
# 32160  3906253176                 Visa
# 32400  3906257580  Advantage Solutions
#
#                                                    title  \
# 44                               Associate Brand Manager
# 195                                      Product Manager
# 441                       VP Agency Partnerships, Indies
# 550        Experience Product Manager Associate Director
# 551    Associate Director Market Research Competitive...
# ...                                                  ...
# 32143                           Pricing Manager - Remote
# 32157  Sr Director - Consulting & Analytics - Nationa...
# 32159  Program Manager, Client Consulting, VCA Risk P...
# 32160  Program Manager, Client Consulting, VCA Risk P...
# 32400                          Director, Client Services
#
#                                              description  max_salary  \
# 44     Job Title: Associate Brand Manager / Brand Man...     90000.0
# 195    Swipeclock is on a mission to make working lif...    120000.0
# 441    Role: VP Agency Partnerships, Indies\n\nLocati...    250000.0
# 550    Help us change lives\n\nAt Exact Sciences, we’...    242000.0
# 551    Job Description\n\nDuties\n\nThe Senior Associ...    187200.0
# ...                                                  ...         ...
# 32143  At Wolters Kluwer, our mission is to deliver d...    164700.0
# 32157  Company Description\n\nVisa is a world leader ...    301150.0
# 32159  Company Description\n\nVisa is a world leader ...    191800.0
# 32160  Company Description\n\nVisa is a world leader ...    191800.0
# 32400  Director Client Services \n\nAt our Company, w...    105000.0
#
#                    location  company_id  views  min_salary  \
# 44              Waltham, MA  40692980.0    1.0     75000.0
# 195        South Jordan, UT    940888.0    3.0    100000.0
# 441            New York, NY   2883353.0   38.0    210000.0
# 550             Madison, WI     48835.0   38.0    152000.0
# 551    Fairfield County, CT   2474662.0   10.0    124800.0
# ...                     ...         ...    ...         ...
# 32143  Texas, United States      2483.0    4.0    117500.0
# 32157        Washington, DC      2190.0    4.0    173400.0
# 32159           Ashburn, VA      2190.0    4.0    112500.0
# 32160       Foster City, CA      2190.0    4.0    112500.0
# 32400       Bentonville, AR      9123.0    4.0     75000.0
#
#       formatted_work_type  ...  \
# 44              Full-time  ...
# 195             Full-time  ...
# 441             Full-time  ...
# 550             Full-time  ...
# 551             Full-time  ...
# ...                   ...  ...
# 32143           Full-time  ...
# 32157           Full-time  ...
# 32159           Full-time  ...
# 32160           Full-time  ...
# 32400           Full-time  ...
#
#                                              soft_skills  \
# 44            communication, problem-solving, leadership
# 195               communication, problem-solving, detail
# 441    communication, problem-solving, leadership, de...
# 550    communication, teamwork, problem-solving, lead...
# 551                            communication, leadership
# ...                                                  ...
# 32143           communication, leadership, collaboration
# 32157                  communication, leadership, detail
# 32159                  communication, leadership, detail
# 32160                  communication, leadership, detail
# 32400        communication, leadership, detail, deadline
#
#       programming_languages_score analysis_statistics_score  \
# 44                              1                         1
# 195                             1                         1
# 441                             1                         1
# 550                             1                         2
# 551                             1                         1
# ...                           ...                       ...
# 32143                           1                         2
# 32157                           1                         1
# 32159                           1                         1
# 32160                           1                         1
# 32400                           1                         1
#
#       machine_learning_score data_visualization_score cloud_platform_score  \
# 44                         1                        1                    1
# 195                        1                        1                    0
# 441                        1                        1                    0
# 550                        1                        2                    0
# 551                        1                        1                    0
# ...                      ...                      ...                  ...
# 32143                      1                        1                    0
# 32157                      1                        1                    0
# 32159                      1                        1                    0
# 32160                      1                        1                    0
# 32400                      1                        1                    0
#
#        database_score  big_data_tools_score big_data_score  \
# 44                  0                     0              0
# 195                 0                     0              0
# 441                 0                     0              0
# 550                 0                     0              0
# 551                 0                     0              0
# ...               ...                   ...            ...
# 32143               1                     0              0
# 32157               0                     0              0
# 32159               0                     0              0
# 32160               0                     0              0
# 32400               0                     0              0
#
#       business_engineering_score
# 44                             0
# 195                            0
# 441                            0
# 550                            0
# 551                            0
# ...                          ...
# 32143                          0
# 32157                          0
# 32159                          0
# 32160                          0
# 32400                          0
#
# [583 rows x 44 columns]

# %%
data_job[(data_job['job_classification']== "Engineering")]
# Out:
#            job_id                                       company_name  \
# 4        95428182                           CLEVELAND KIDS BOOK BANK
# 11     1014822088                                            Tracker
# 30     3189117072        Signature Estate & Investment Advisors, LLC
# 32     3260455681                                       Weyerhaeuser
# 35     3297645846            Navajo Transitional Energy Company, LLC
# ...           ...                                                ...
# 32501  3906260068                                            Workday
# 32519  3906260689  Volkswagen Group of America Innovation and Eng...
# 32532  3906262009                                          Solugenix
# 32533  3906262044                                           Legal.io
# 32546  3906265006                                         Applicantz
#
#                                              title  \
# 4                       Administrative Coordinator
# 11                            Marketing Specialist
# 30     Client Service Associate / Practice Manager
# 32                           Operations Specialist
# 35                          Contract Administrator
# ...                                            ...
# 32501  Senior Associate Quality Assurance Engineer
# 32519                                iOS Developer
# 32532       Senior Business Intelligence Developer
# 32533                      Privacy Program Manager
# 32546               SAP FICO Functional Consultant
#
#                                              description  max_salary  \
# 4      Job Title: Administrative CoordinatorOrganizat...         NaN
# 11     About TrackerTracker is a leading global cloud...     80000.0
# 30     Company OverviewSignature Estate and Investmen...    100000.0
# 32     Weyerhaeuser is searching for a Operations Spe...    109113.0
# 35     Contract AdministratorSummary of PositionThe C...     90000.0
# ...                                                  ...         ...
# 32501  Your work days are brighter here.\n\nAt Workda...    151200.0
# 32519  VW. Two letters. Endless opportunities. A brig...    190000.0
# 32532  Senior Business Intelligence DeveloperLos Ange...    141440.0
# 32533  Legal.io is working with a leading automotive ...    187200.0
# 32546  VISA SPONSORSHIP IS NOT AVAILABLE. Remote role...    186492.8
#
#                 location  company_id  views  min_salary formatted_work_type  \
# 4          Cleveland, OH  55624331.0    1.0         NaN           Full-time
# 11         United States    255252.0    7.0     70000.0           Full-time
# 30     Redondo Beach, CA   1299114.0    6.0     70000.0           Full-time
# 32       Castle Rock, WA      4494.0   18.0     72742.0           Full-time
# 35        Broomfield, CO  59475546.0    6.0     74400.0           Full-time
# ...                  ...         ...    ...         ...                 ...
# 32501        Atlanta, GA     17719.0    4.0     74500.0           Full-time
# 32519        Belmont, CA  29308364.0    5.0    128400.0           Full-time
# 32532    Los Angeles, CA     43325.0    3.0    133120.0            Contract
# 32533      United States   6452409.0    3.0    135200.0            Contract
# 32546      United States     24629.0    3.0    186492.8            Contract
#
#        ...                                       soft_skills  \
# 4      ...  communication, creativity, detail, collaboration
# 11     ...                                  detail, deadline
# 30     ...                   communication, detail, deadline
# 32     ...                 communication, leadership, detail
# 35     ...                             communication, detail
# ...    ...                                               ...
# 32501  ...                             communication, detail
# 32519  ...                                     communication
# 32532  ...  communication, teamwork, problem-solving, detail
# 32533  ...                             communication, detail
# 32546  ...                                creativity, detail
#
#       programming_languages_score analysis_statistics_score  \
# 4                               1                         1
# 11                              1                         0
# 30                              1                         0
# 32                              1                         1
# 35                              1                         1
# ...                           ...                       ...
# 32501                           3                         2
# 32519                           4                         0
# 32532                           2                         3
# 32533                           1                         0
# 32546                           1                         1
#
#       machine_learning_score data_visualization_score cloud_platform_score  \
# 4                          1                        1                    2
# 11                         1                        1                    1
# 30                         1                        1                    1
# 32                         1                        1                    1
# 35                         1                        2                    0
# ...                      ...                      ...                  ...
# 32501                      1                        1                    1
# 32519                      1                        1                    0
# 32532                      1                        3                    0
# 32533                      1                        1                    0
# 32546                      1                        1                    0
#
#        database_score  big_data_tools_score big_data_score  \
# 4                   1                     0              0
# 11                  0                     0              0
# 30                  1                     0              0
# 32                  0                     0              0
# 35                  0                     0              0
# ...               ...                   ...            ...
# 32501               0                     0              0
# 32519               0                     0              0
# 32532               2                     0              0
# 32533               0                     0              0
# 32546               0                     0              0
#
#       business_engineering_score
# 4                              0
# 11                             0
# 30                             0
# 32                             0
# 35                             0
# ...                          ...
# 32501                          0
# 32519                          0
# 32532                          0
# 32533                          0
# 32546                          0
#
# [4449 rows x 44 columns]

# %%
# Filter the DataFrame for rows where normalized_salary is in the specified range
filtered_data = data_job[(data_job["normalized_salary"] > 5000) & (data_job["normalized_salary"] < 20000)]

# Update the normalized_salary column by multiplying it by 12
data_job.loc[(data_job["normalized_salary"] > 5000) & (data_job["normalized_salary"] < 20000), "normalized_salary"] *= 12

# %%
# Filter the DataFrame for rows where normalized_salary is in the specified range
filtered_data1 = data_job[(data_job["normalized_salary"] < 1000)]

data_job.loc[data_job["normalized_salary"] < 1000, "normalized_salary"] =((data_job["max_salary"] + data_job["min_salary"]) / 2 * 2080)

# %%
data_job["normalized_salary"].describe()
# Out:
# count    5.958000e+03
# mean     1.313777e+05
# std      1.327843e+06
# min      2.000050e+04
# 25%      7.550000e+04
# 50%      1.050000e+05
# 75%      1.400000e+05
# max      1.025000e+08
# Name: normalized_salary, dtype: float64

# %%
# Save the processed dataset
#data_job.to_csv('processed_job_postings_nltk_v2.csv', index=False)
